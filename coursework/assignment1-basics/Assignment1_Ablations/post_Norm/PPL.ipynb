# %% [markdown]
# <img width="640" height="480" alt="train_ppl2" src="https://github.com/user-attachments/assets/cb3cdf93-0841-4c0e-952d-519ed4fde73c" />
#
#
#
# <img width="640" height="480" alt="val_ppl" src="https://github.com/user-attachments/assets/b7a4a78a-a3f7-473e-8f6b-9df7b5339f1a" />
